# %%
using Revise, Hecke
# Out:
# Welcome to Nemo version 0.12.1
#
# Nemo comes with absolutely no warranty whatsoever
# $\require{action}$
# Welcome to
#
#     _    _           _
#    | |  | |         | |
#    | |__| | ___  ___| | _____
#    |  __  |/ _ \/ __| |/ / _ \
#    | |  | |  __/ (__|   <  __/
#    |_|  |_|\___|\___|_|\_\___|
#
# Version 0.6.0 ...
#  ... which comes with absolutely no warranty whatsoever
# (c) 2015-2019 by Claus Fieker, Tommy Hofmann and Carlo Sircana

# %%
Hecke.example("Francy.jl")

# %%
graphic_divisors(fmpz(125))
# Out:
# Main.Francy.Canvas(Dict{Symbol,Any}(:texTypesetting=>false,:graph=>Dict{Symbol,Any}(:links=>Dict{Any,Any}("id28"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id28",:title=>"",:source=>"id5",:target=>"id4",:length=>0),"id23"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id23",:title=>"",:source=>"id3",:target=>"id2",:length=>0),"id25"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id25",:title=>"",:source=>"id4",:target=>"id3",:length=>0),"id24"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id24",:title=>"",:source=>"id4",:target=>"id2",:length=>0),"id27"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id27",:title=>"",:source=>"id5",:target=>"id3",:length=>0),"id26"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id26",:title=>"",:source=>"id5",:target=>"id2",:length=>0)),:id=>"id22",:type=>:directed,:simulation=>false,:collapsed=>true,:nodes=>Dict{Any,Any}("id2"=>Dict{Symbol,Any}(
# ...

# %%
A = GrpAbFinGen([3,3,3])
# Out:
# GrpAb: Z/3^3

# %%
FrancyExample.graphic_subgroups(A)
# Out:
# Main.Francy.Canvas(Dict{Symbol,Any}(:texTypesetting=>false,:graph=>Dict{Symbol,Any}(:links=>Dict{Any,Any}("id91"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id91",:title=>"",:source=>"id32",:target=>"id48",:length=>0),"id161"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id161",:title=>"",:source=>"id55",:target=>"id57",:length=>0),"id81"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id81",:title=>"",:source=>"id30",:target=>"id54",:length=>0),"id77"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id77",:title=>"",:source=>"id30",:target=>"id50",:length=>0),"id162"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id162",:title=>"",:source=>"id56",:target=>"id57",:length=>0),"id126"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id126",:title=>"",:source=>"id39",:target=>"id48",:length=>0),"id93"=>Dict{Symbol,Any}(:color=>"",:invisible=>false,:weight=>0,:id=>"id93",:title=>"",:sourc
# ...

# %%
c = canvas("hi");
g = graph();
push!(c, g);
for t = [ :triangle, :diamond,:circle,:square,:cross,:star,:wye]
    push!(g, shape(string(t), t))
end
c
# Out:
# Main.Francy.Canvas(Dict{Symbol,Any}(:texTypesetting=>false,:graph=>Dict{Symbol,Any}(:links=>Dict{Any,Any}(),:id=>"id165",:type=>:directed,:simulation=>false,:collapsed=>true,:nodes=>Dict{Any,Any}("id172"=>Dict{Symbol,Any}(:menus=>Dict{Any,Any}(),:size=>10,:title=>"wye",:x=>0,:callbacks=>Dict{Any,Any}(),:color=>"",:id=>"id172",:type=>:wye,:y=>0,:layer=>0…),"id166"=>Dict{Symbol,Any}(:menus=>Dict{Any,Any}(),:size=>10,:title=>"triangle",:x=>0,:callbacks=>Dict{Any,Any}(),:color=>"",:id=>"id166",:type=>:triangle,:y=>0,:layer=>0…),"id169"=>Dict{Symbol,Any}(:menus=>Dict{Any,Any}(),:size=>10,:title=>"square",:x=>0,:callbacks=>Dict{Any,Any}(),:color=>"",:id=>"id169",:type=>:square,:y=>0,:layer=>0…),"id171"=>Dict{Symbol,Any}(:menus=>Dict{Any,Any}(),:size=>10,:title=>"star",:x=>0,:callbacks=>Dict{Any,Any}(),:color=>"",:id=>"id171",:type=>:star,:y=>0,:layer=>0…),"id167"=>Dict{Symbol,Any}(:menus=>Dict{Any,Any}(),:size=>10,:title=>"diamond",:x=>0,:callbacks=>Dict{Any,Any}(),:color=>"",:id=>"id167",
# ...
